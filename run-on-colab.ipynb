# %%
# !nvidia-smi
# Out:
# Sat Feb 14 04:34:35 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/Othercomputers/'我的 Mac'/GoogleDrive/nanochat
# Out:
# Mounted at /content/drive
# /content/drive/Othercomputers/我的 Mac/GoogleDrive/nanochat

# %%
# !ls
# Out:
# dev	 nanochat	 README.md	     runs     tasks  uv.lock
# LICENSE  pyproject.toml  run-on-colab.ipynb  scripts  tests

# %%
# !bash runs/speedrun-colab.sh

# %% [markdown]
# ## Testing Tokenizer
